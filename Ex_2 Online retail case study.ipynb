# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/home/parth/Downloads/FML Lab/Dataset/online_retail_II.csv")

# %%
df.info
# Out:
# <bound method DataFrame.info of         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1067366  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                              POSTAGE         1
#
# ...

# %%
df.isnull().sum()
# Out:
# Invoice             0
# StockCode           0
# Description      4382
# Quantity            0
# InvoiceDate         0
# Price               0
# Customer ID    243007
# Country             0
# dtype: int64

# %%
df.shape
# Out:
# (1067371, 8)

# %%
print("Number of transactions: ",df['Invoice'].nunique())
print("Number of products: ",df['StockCode'].nunique())
print("Number of customers:", df['Customer ID'].nunique() )
# Out:
# Number of transactions:  53628
# Number of products:  5305
# Number of customers: 5942

# %%
print("Percentage of customers NA: ", round(df['Customer ID'].isnull().sum() * 100 /len(df),2),"%" )
# Out:
# Percentage of customers NA:  22.77 %

# %%
print('Number of countries: ',df['Country'].nunique())
# Out:
# Number of countries:  43

# %%
#analysis on quantitative data
df.describe()
# Out:
#            Quantity         Price    Customer ID
# count  1.067371e+06  1.067371e+06  824364.000000
# mean   9.938898e+00  4.649388e+00   15324.638504
# std    1.727058e+02  1.235531e+02    1697.464450
# min   -8.099500e+04 -5.359436e+04   12346.000000
# 25%    1.000000e+00  1.250000e+00   13975.000000
# 50%    3.000000e+00  2.100000e+00   15255.000000
# 75%    1.000000e+01  4.150000e+00   16797.000000
# max    8.099500e+04  3.897000e+04   18287.000000

# %%
cancelled_orders = df[df['Invoice'].astype(str).str.contains('C')]
cancelled_orders.head()
# Out:
#      Invoice StockCode                    Description  Quantity  \
# 178  C489449     22087       PAPER BUNTING WHITE LACE       -12
# 179  C489449    85206A   CREAM FELT EASTER EGG BASKET        -6
# 180  C489449     21895  POTTING SHED SOW 'N' GROW SET        -4
# 181  C489449     21896             POTTING SHED TWINE        -6
# 182  C489449     22083     PAPER CHAIN KIT RETRO SPOT       -12
#
#              InvoiceDate  Price  Customer ID    Country
# 178  2009-12-01 10:33:00   2.95      16321.0  Australia
# 179  2009-12-01 10:33:00   1.65      16321.0  Australia
# 180  2009-12-01 10:33:00   4.25      16321.0  Australia
# 181  2009-12-01 10:33:00   2.10      16321.0  Australia
# 182  2009-12-01 10:33:00   2.95      16321.0  Australia

# %%
#search for transaction where quantity == -80995
cancelled_orders[cancelled_orders['Quantity']==-80995]
# Out:
#          Invoice StockCode                  Description  Quantity  \
# 1065883  C581484     23843  PAPER CRAFT , LITTLE BIRDIE    -80995
#
#                  InvoiceDate  Price  Customer ID         Country
# 1065883  2011-12-09 09:27:00   2.08      16446.0  United Kingdom

# %%
#check how many rows our dataframe contains cancelled orders
print("We have ",len(cancelled_orders), " cancelled orders.")
# Out:
# We have  19494  cancelled orders.

# %%
#percentage of cancelled orders in total orders
total_orders = df['Invoice'].nunique()

# %%
cancelled_number = len(cancelled_orders)
print('Percentage of orders canceled: {}/{} ({:.2f}%) '.format(cancelled_number, total_orders,cancelled_number/total_orders*100))
# Out:
# Percentage of orders canceled: 19494/53628 (36.35%)

# %%
#Customers by country
df['total_cost'] = df['Quantity'] * df['Price']
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#            InvoiceDate  Price  Customer ID         Country  total_cost
# 0  2009-12-01 07:45:00   6.95      13085.0  United Kingdom        83.4
# 1  2009-12-01 07:45:00   6.75      13085.0  United Kingdom        81.0
# 2  2009-12-01 07:45:00   6.75      13085.0  United Kingdom        81.0
# 3  2009-12-01 07:45:00   2.10      13085.0  United Kingdom       100.8
# 4  2009-12-01 07:45:00   1.25      13085.0  United Kingdom        30.0

# %%
df.groupby('Country').sum().sort_values(by='total_cost', ascending=False)
# Out:
#                       Quantity        Price   Customer ID    total_cost
# Country
# United Kingdom         8692875  4453169.287  1.153023e+10  1.638258e+07
# EIRE                    331341   125305.450  2.379617e+08  6.155196e+05
# Netherlands             381951    15663.230  7.295077e+07  5.485249e+05
# Germany                 224581    67564.451  2.227093e+08  4.179886e+05
# France                  184952    67231.310  1.801614e+08  3.281918e+05
# Australia               103706     8111.070  2.388868e+07  1.671291e+05
# Switzerland              52378    12049.880  3.869831e+07  9.972876e+04
# Spain                    45156    20539.470  4.913592e+07  9.185948e+04
# Sweden                   87875     8709.920  1.836395e+07  8.780942e+04
# Denmark                 235218     2397.890  1.036590e+07  6.574109e+04
# Belgium                  35132    14766.880  3.887363e+07  6.357449e+04
# Portugal                 28058    17125.840  3.189725e+07  5.313680e+04
# ...

# %%
#Checking for null attributes
df.isnull().sum()
# Out:
# Invoice             0
# StockCode           0
# Description      4382
# Quantity            0
# InvoiceDate         0
# Price               0
# Customer ID    243007
# Country             0
# total_cost          0
# dtype: int64

# %%
#Dropping entire null attributes row 
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# Invoice        0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# Price          0
# Customer ID    0
# Country        0
# total_cost     0
# dtype: int64

# %%
df.tail()
# Out:
#         Invoice StockCode                      Description  Quantity  \
# 1067366  581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 1067367  581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 1067368  581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 1067369  581587     22138    BAKING SET 9 PIECE RETROSPOT          3
# 1067370  581587      POST                          POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID Country  total_cost
# 1067366  2011-12-09 12:50:00   2.10      12680.0  France       12.60
# 1067367  2011-12-09 12:50:00   4.15      12680.0  France       16.60
# 1067368  2011-12-09 12:50:00   4.15      12680.0  France       16.60
# 1067369  2011-12-09 12:50:00   4.95      12680.0  France       14.85
# 1067370  2011-12-09 12:50:00  18.00      12680.0  France       18.00
