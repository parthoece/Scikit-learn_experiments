# %%
import sklearn.datasets
import pandas as pd 
data, target = sklearn.datasets.load_iris(return_X_y=True, as_frame=True)
data["target"] = target
print(data)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [5], in <cell line: 2>()
#       1 import sklearn.datasets as dt
# ----> 2 import pandas as pd
#       3 data, target = dt.load_iris(return_X_y=True, as_frame=True)
#       4 data["target"] = target
#
# File ~/anaconda3/envs/tfenv/lib/python3.8/site-packages/pandas/__init__.py:144, in <module>
#     141 import pandas.api
#     142 from pandas.util._print_versions import show_versions
# --> 144 from pandas.io.api import (
#     145     # excel
#     146     ExcelFile,
#     147     ExcelWriter,
#     148     read_excel,
#     149     # parsers
#     150     read_csv,
#     151     read_fwf,
#     152     read_table,
#     153     # pickle
#     154     read_pickle,
#     155     to_pickle,
#     156     # pytables
#     157     HDFStore,
#     158     read_hdf,
#     159     # sql
#     160     read_sql,
# ...
